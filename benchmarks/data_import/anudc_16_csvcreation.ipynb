# %%
import numpy as np
import pandas as pd
import os

# %%
root = "Y:/g/data/eu59/data_flowmop/fig_4_data/anudc_16"

sample_metadata = pd.read_csv(os.path.join(root, "anu_dc_metadata_cellsfiltered.csv"), sep = ';')

# %%
base_metadata = pd.DataFrame()
base_metadata["base_name"] = [os.path.splitext(os.path.basename(path))[0] for path in sample_metadata["filename"]]
base_metadata["label"] = sample_metadata["tumour"]

# %%
base_metadata.to_csv("Y:/g/data/eu59/data_flowmop/fig_4_data/anudc_16/base_metadata.csv", index = False)
