# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
from ranking_analysis_comparison import bradley_terry_analysis, plot_bradley_terry_results

# %%
data_root = r"D:/github_remotes/FlowMOP_paper/figs_data/fig_3_data/fig_3_analysis"

# %%
time = pd.read_excel(data_root + "/ranking_analysis.xlsx", sheet_name= "Time")
debris = pd.read_excel(data_root + "/ranking_analysis.xlsx", sheet_name = "Debris")
doublets = pd.read_excel(data_root + "/ranking_analysis.xlsx", sheet_name = "Doublets")

time = time.iloc[:,1:]
debris = debris.iloc[:,1:]
doublets = doublets.iloc[:,1:]

# %% [markdown]
# # Frequentist Bradley Terry Analysis

# %%
results_inf = bradley_terry_analysis(
    df=time,
    target_benchmarker=5,
    test_type='inferiority', 
    compare_against=[1, 2, 3, 4],
    fdr_level=0.05,
    use_fdr_correction=True,
    verbose=True
)

plot_bradley_terry_results(
    results_inf, 
    target_benchmarker=5
)
# Out:
# Found 7 benchmarkers: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7)]
# Analyzing benchmarker 5
# Test type: INFERIORITY
# Comparing against: [1, 2, 3, 4]
# Using two-stage FDR correction at level 0.05
#
# ============================================================
# Created 189 pairwise comparisons from rankings
#
# Bradley-Terry Ability Estimates:
# (Higher ability = better performance)
# ----------------------------------------
#  benchmarker_id  ability       se  lower_ci  upper_ci
#               1 3.740982 0.658706  2.449943  5.032021
#               2 1.939420 0.554822  0.851989  3.026852
#               3 4.643741 0.719618  3.233316  6.054167
#               4 3.623623 0.651983  2.345760  4.901487
#               5 1.171193 0.518859  0.154248  2.188137
#               6 0.128838 0.508189 -0.867195  1.124870
#               7 0.000000 0.000000  0.000000  0.000000
#
# ============================================================
# INFERIORITY TEST: Is Benchmarker 5 INFERIOR to [1, 2, 3, 4]?
# ------------------------------------------------------------
# Two-stage FDR correction applied (FDR level = 0.05)
# Adjusted alpha level: 0.2000
# ------------------------------------------------------------
#
# Benchmarker 5 vs 1:
#   Ability difference: -2.570 ± 0.839
#   P(B5 < B1): 0.999
#   P-value (raw): 0.0011
#   P-value (FDR-adjusted): 0.0022
#   Reject null (FDR): True
#
# Benchmarker 5 vs 2:
#   Ability difference: -0.768 ± 0.760
#   P(B5 < B2): 0.844
#   P-value (raw): 0.1559
#   P-value (FDR-adjusted): 0.1559
#   Reject null (FDR): True
#
# Benchmarker 5 vs 3:
#   Ability difference: -3.473 ± 0.887
#   P(B5 < B3): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0002
#   Reject null (FDR): True
#
# Benchmarker 5 vs 4:
#   Ability difference: -2.452 ± 0.833
#   P(B5 < B4): 0.998
#   P-value (raw): 0.0016
#   P-value (FDR-adjusted): 0.0022
#   Reject null (FDR): True
#
# ============================================================
# CONCLUSIONS (with FDR correction)
# ============================================================
# ✓ Significant evidence (FDR-controlled at 0.05) that Benchmarker 5 is INFERIOR to all of [1, 2, 3, 4]
#
# ============================================================
# MODEL DIAGNOSTICS
# ============================================================
# AIC: 145.82
# BIC: -825.42
# Log-Likelihood: -66.91
# Pseudo R-squared: 398602554370696.0625

# %%
results_inf = bradley_terry_analysis(
    df=time,
    target_benchmarker=6,
    test_type='inferiority', 
    compare_against=[1, 2, 3, 4],
    fdr_level=0.05,
    use_fdr_correction=True,
    verbose=True
)

plot_bradley_terry_results(
    results_inf, 
    target_benchmarker=6
)
# Out:
# Found 7 benchmarkers: [1, 2, 3, 4, 5, 6, 7]
# Analyzing benchmarker 6
# Test type: INFERIORITY
# Comparing against: [1, 2, 3, 4]
# Using two-stage FDR correction at level 0.05
#
# ============================================================
# Created 189 pairwise comparisons from rankings
#
# Bradley-Terry Ability Estimates:
# (Higher ability = better performance)
# ----------------------------------------
#  benchmarker_id  ability       se  lower_ci  upper_ci
#               1 3.740982 0.658706  2.449943  5.032021
#               2 1.939420 0.554822  0.851989  3.026852
#               3 4.643741 0.719618  3.233316  6.054167
#               4 3.623623 0.651983  2.345760  4.901487
#               5 1.171193 0.518859  0.154248  2.188137
#               6 0.128838 0.508189 -0.867195  1.124870
#               7 0.000000 0.000000  0.000000  0.000000
#
# ============================================================
# INFERIORITY TEST: Is Benchmarker 6 INFERIOR to [1, 2, 3, 4]?
# ------------------------------------------------------------
# Two-stage FDR correction applied (FDR level = 0.05)
# Adjusted alpha level: 0.2000
# ------------------------------------------------------------
#
# Benchmarker 6 vs 1:
#   Ability difference: -3.612 ± 0.832
#   P(B6 < B1): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0000
#   Reject null (FDR): True
#
# Benchmarker 6 vs 2:
#   Ability difference: -1.811 ± 0.752
#   P(B6 < B2): 0.992
#   P-value (raw): 0.0081
#   P-value (FDR-adjusted): 0.0081
#   Reject null (FDR): True
#
# Benchmarker 6 vs 3:
#   Ability difference: -4.515 ± 0.881
#   P(B6 < B3): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0000
#   Reject null (FDR): True
#
# Benchmarker 6 vs 4:
#   Ability difference: -3.495 ± 0.827
#   P(B6 < B4): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0000
#   Reject null (FDR): True
#
# ============================================================
# CONCLUSIONS (with FDR correction)
# ============================================================
# ✓ Significant evidence (FDR-controlled at 0.05) that Benchmarker 6 is INFERIOR to all of [1, 2, 3, 4]
#
# ============================================================
# MODEL DIAGNOSTICS
# ============================================================
# AIC: 145.82
# BIC: -825.42
# Log-Likelihood: -66.91
# Pseudo R-squared: 531470072494261.0625

# %%
results_inf = bradley_terry_analysis(
    df=time,
    target_benchmarker=7,
    test_type='inferiority', 
    compare_against=[1, 2, 3, 4],
    fdr_level=0.05,
    use_fdr_correction=True,
    verbose=True
)

plot_bradley_terry_results(
    results_inf, 
    target_benchmarker=7
)
# Out:
# Found 7 benchmarkers: [1, 2, 3, 4, 5, 6, 7]
# Analyzing benchmarker 7
# Test type: INFERIORITY
# Comparing against: [1, 2, 3, 4]
# Using two-stage FDR correction at level 0.05
#
# ============================================================
# Created 189 pairwise comparisons from rankings
#
# Bradley-Terry Ability Estimates:
# (Higher ability = better performance)
# ----------------------------------------
#  benchmarker_id  ability       se  lower_ci  upper_ci
#               1 3.740982 0.658706  2.449943  5.032021
#               2 1.939420 0.554822  0.851989  3.026852
#               3 4.643741 0.719618  3.233316  6.054167
#               4 3.623623 0.651983  2.345760  4.901487
#               5 1.171193 0.518859  0.154248  2.188137
#               6 0.128838 0.508189 -0.867195  1.124870
#               7 0.000000 0.000000  0.000000  0.000000
#
# ============================================================
# INFERIORITY TEST: Is Benchmarker 7 INFERIOR to [1, 2, 3, 4]?
# ------------------------------------------------------------
# Two-stage FDR correction applied (FDR level = 0.05)
# Adjusted alpha level: 0.2000
# ------------------------------------------------------------
#
# Benchmarker 7 vs 1:
#   Ability difference: -3.741 ± 0.659
#   P(B7 < B1): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0000
#   Reject null (FDR): True
#
# Benchmarker 7 vs 2:
#   Ability difference: -1.939 ± 0.555
#   P(B7 < B2): 1.000
#   P-value (raw): 0.0002
#   P-value (FDR-adjusted): 0.0002
#   Reject null (FDR): True
#
# Benchmarker 7 vs 3:
#   Ability difference: -4.644 ± 0.720
#   P(B7 < B3): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0000
#   Reject null (FDR): True
#
# Benchmarker 7 vs 4:
#   Ability difference: -3.624 ± 0.652
#   P(B7 < B4): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0000
#   Reject null (FDR): True
#
# ============================================================
# CONCLUSIONS (with FDR correction)
# ============================================================
# ✓ Significant evidence (FDR-controlled at 0.05) that Benchmarker 7 is INFERIOR to all of [1, 2, 3, 4]
#
# ============================================================
# MODEL DIAGNOSTICS
# ============================================================
# AIC: 145.82
# BIC: -825.42
# Log-Likelihood: -66.91
# Pseudo R-squared: 531470072494261.0625

# %%
results_superiority = bradley_terry_analysis(
    df=time,
    target_benchmarker=5,
    test_type='superiority', 
    compare_against=[6, 7],
    fdr_level=0.05,
    use_fdr_correction=True,
    verbose=True
)

plot_bradley_terry_results(
    results_superiority, 
    target_benchmarker=1
)
# Out:
# Found 7 benchmarkers: [1, 2, 3, 4, 5, 6, 7]
# Analyzing benchmarker 5
# Test type: SUPERIORITY
# Comparing against: [6, 7]
# Using two-stage FDR correction at level 0.05
#
# ============================================================
# Created 189 pairwise comparisons from rankings
#
# Bradley-Terry Ability Estimates:
# (Higher ability = better performance)
# ----------------------------------------
#  benchmarker_id  ability       se  lower_ci  upper_ci
#               1 3.740982 0.658706  2.449943  5.032021
#               2 1.939420 0.554822  0.851989  3.026852
#               3 4.643741 0.719618  3.233316  6.054167
#               4 3.623623 0.651983  2.345760  4.901487
#               5 1.171193 0.518859  0.154248  2.188137
#               6 0.128838 0.508189 -0.867195  1.124870
#               7 0.000000 0.000000  0.000000  0.000000
#
# ============================================================
# SUPERIORITY TEST: Is Benchmarker 5 SUPERIOR to [6, 7]?
# ------------------------------------------------------------
# Two-stage FDR correction applied (FDR level = 0.05)
# Adjusted alpha level: 0.1000
# ------------------------------------------------------------
#
# Benchmarker 5 vs 6:
#   Ability difference: 1.042 ± 0.726
#   P(B5 > B6): 0.924
#   P-value (raw): 0.0756
#   P-value (FDR-adjusted): 0.0756
#   Reject null (FDR): True
#
# Benchmarker 5 vs 7:
#   Ability difference: 1.171 ± 0.519
#   P(B5 > B7): 0.988
#   P-value (raw): 0.0120
#   P-value (FDR-adjusted): 0.0240
#   Reject null (FDR): True
#
# ============================================================
# CONCLUSIONS (with FDR correction)
# ============================================================
# ✓ Significant evidence (FDR-controlled at 0.05) that Benchmarker 5 is SUPERIOR to all of [6, 7]
#
# ============================================================
# MODEL DIAGNOSTICS
# ============================================================
# AIC: 145.82
# BIC: -825.42
# Log-Likelihood: -66.91
# Pseudo R-squared: 531470072494261.0625

# %%
results_inf = bradley_terry_analysis(
    df=debris,
    target_benchmarker=5,
    test_type='inferiority', 
    compare_against=[1, 2, 3, 4],
    fdr_level=0.05,
    use_fdr_correction=True,
    verbose=True
)
# Out:
# Found 5 benchmarkers: [1, 2, 3, 4, 5]
# Analyzing benchmarker 5
# Test type: INFERIORITY
# Comparing against: [1, 2, 3, 4]
# Using two-stage FDR correction at level 0.05
#
# ============================================================
# Created 86 pairwise comparisons from rankings
#
# Bradley-Terry Ability Estimates:
# (Higher ability = better performance)
# ----------------------------------------
#  benchmarker_id  ability       se  lower_ci  upper_ci
#               1 0.255538 0.507619 -0.739378  1.250454
#               2 2.324737 0.603377  1.142140  3.507334
#               3 2.465263 0.615907  1.258107  3.672418
#               4 0.750883 0.525263 -0.278614  1.780380
#               5 0.000000 0.000000  0.000000  0.000000
#
# ============================================================
# INFERIORITY TEST: Is Benchmarker 5 INFERIOR to [1, 2, 3, 4]?
# ------------------------------------------------------------
# Two-stage FDR correction applied (FDR level = 0.05)
# Adjusted alpha level: 0.1000
# ------------------------------------------------------------
#
# Benchmarker 5 vs 1:
#   Ability difference: -0.256 ± 0.508
#   P(B5 < B1): 0.693
#   P-value (raw): 0.3073
#   P-value (FDR-adjusted): 0.3073
#   Reject null (FDR): False
#
# Benchmarker 5 vs 2:
#   Ability difference: -2.325 ± 0.603
#   P(B5 < B2): 1.000
#   P-value (raw): 0.0001
#   P-value (FDR-adjusted): 0.0001
#   Reject null (FDR): True
#
# Benchmarker 5 vs 3:
#   Ability difference: -2.465 ± 0.616
#   P(B5 < B3): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0001
#   Reject null (FDR): True
#
# Benchmarker 5 vs 4:
#   Ability difference: -0.751 ± 0.525
#   P(B5 < B4): 0.924
#   P-value (raw): 0.0764
#   P-value (FDR-adjusted): 0.1019
#   Reject null (FDR): False
#
# ============================================================
# CONCLUSIONS (with FDR correction)
# ============================================================
# ✓ Significant evidence (FDR-controlled) that Benchmarker 5 is inferior to [2, 3]
#
# ============================================================
# MODEL DIAGNOSTICS
# ============================================================
# AIC: 90.06
# BIC: -283.19
# Log-Likelihood: -41.03
# Pseudo R-squared: 716231866292943.7500

# %%
results_inf = bradley_terry_analysis(
    df=doublets,
    target_benchmarker=5,
    test_type='inferiority', 
    compare_against=[1, 2, 3, 4],
    fdr_level=0.05,
    use_fdr_correction=True,
    verbose=True
)
# Out:
# Found 5 benchmarkers: [1, 2, 3, 4, 5]
# Analyzing benchmarker 5
# Test type: INFERIORITY
# Comparing against: [1, 2, 3, 4]
# Using two-stage FDR correction at level 0.05
#
# ============================================================
# Created 86 pairwise comparisons from rankings
#
# Bradley-Terry Ability Estimates:
# (Higher ability = better performance)
# ----------------------------------------
#  benchmarker_id  ability       se  lower_ci  upper_ci
#               1 1.082004 0.492450  0.116819  2.047189
#               2 0.978996 0.489531  0.019533  1.938458
#               3 2.480216 0.606999  1.290519  3.669912
#               4 0.876045 0.487170 -0.078791  1.830880
#               5 0.000000 0.000000  0.000000  0.000000
#
# ============================================================
# INFERIORITY TEST: Is Benchmarker 5 INFERIOR to [1, 2, 3, 4]?
# ------------------------------------------------------------
# Two-stage FDR correction applied (FDR level = 0.05)
# Adjusted alpha level: 0.2000
# ------------------------------------------------------------
#
# Benchmarker 5 vs 1:
#   Ability difference: -1.082 ± 0.492
#   P(B5 < B1): 0.986
#   P-value (raw): 0.0140
#   P-value (FDR-adjusted): 0.0280
#   Reject null (FDR): True
#
# Benchmarker 5 vs 2:
#   Ability difference: -0.979 ± 0.490
#   P(B5 < B2): 0.977
#   P-value (raw): 0.0228
#   P-value (FDR-adjusted): 0.0303
#   Reject null (FDR): True
#
# Benchmarker 5 vs 3:
#   Ability difference: -2.480 ± 0.607
#   P(B5 < B3): 1.000
#   P-value (raw): 0.0000
#   P-value (FDR-adjusted): 0.0001
#   Reject null (FDR): True
#
# Benchmarker 5 vs 4:
#   Ability difference: -0.876 ± 0.487
#   P(B5 < B4): 0.964
#   P-value (raw): 0.0361
#   P-value (FDR-adjusted): 0.0361
#   Reject null (FDR): True
#
# ============================================================
# CONCLUSIONS (with FDR correction)
# ============================================================
# ✓ Significant evidence (FDR-controlled at 0.05) that Benchmarker 5 is INFERIOR to all of [1, 2, 3, 4]
#
# ============================================================
# MODEL DIAGNOSTICS
# ============================================================
# AIC: 104.07
# BIC: -269.19
# Log-Likelihood: -48.03
# Pseudo R-squared: 838467821971906.1250

# %% [markdown]
# # Bayesian models

# %%
import importlib
import sys
if 'bayesian_analysis' in sys.modules.keys():
    del sys.modules['bayesian_analysis']
from bayesian_analysis import run_bayesian_ranking_analysis, analyze_posterior, plot_posterior_differences, validate_model_fit

# %% [markdown]
# ## Time

# %%
mcmc_results_time = run_bayesian_ranking_analysis(
    df=time,
    n_walkers=32,
    n_steps=5000,
    n_burn=1000,
    prior_std=2.0,
    verbose=True
)
# Out:
# Model type: plackett-luce
# Found 7 benchmarkers: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7)]
# Using benchmarker 1 as reference (ability = 0)
# Running MCMC: 32 walkers, 5000 steps, 1000 burn-in
# Found 9 test rankings
# Average ranking length: 7.0
# Using 15 threads for parallel MCMC sampling
#
# Running MCMC with parallelization...
# MCMC Sampling: 100%|██████████| 5000/5000 [02:17<00:00, 36.32steps/s, Accept=0.520]
# MCMC complete!
# Mean acceptance rate: 0.520
# ✓ Good acceptance rate
# Effective sample size: ~134042 (104.7% efficiency)

# %%
validation_time = validate_model_fit(mcmc_results_time, time, verbose=True)

# Test 1: Superiority
print("\n" + "="*70)
print("TEST 1: Is Benchmarker 5 SUPERIOR to Benchmarkers 6 and 7?")
print("="*70)

superiority_analysis = analyze_posterior(
    results=mcmc_results_time,
    target_benchmarker=5,
    compare_against=[6, 7],
    test_type='superiority',
    credible_level=0.95,
    verbose=True,
    validation=validation_time
)

# Test 2: Inferiority
print("\n" + "="*70)
print("TEST 2: Is Benchmarker 5 INFERIOR to Benchmarkers 1, 2, 3, and 4?")
print("="*70)

inferiority_analysis = analyze_posterior(
    results=mcmc_results_time,
    target_benchmarker=5,
    compare_against=[1, 2, 3, 4],
    test_type='inferiority',
    credible_level=0.95,
    verbose=True,
    validation=validation_time
)
# Out:
# MODEL VALIDATION
# ==================================================
# Chi-square statistic: 7.29
# Number of pairwise comparisons: 21
# Average chi-square per comparison: 0.35
# ✓ Good model fit
#
# ======================================================================
# TEST 1: Is Benchmarker 5 SUPERIOR to Benchmarkers 6 and 7?
# ======================================================================
#
# Posterior Statistics (Reference: Expert 1 = 0)
# ======================================================================
#  benchmarker      mean    median      std  95%_CI_lower  95%_CI_upper
#            3  1.016727  1.013749 0.605587     -0.160125      2.236555
#            4  0.114645  0.122168 0.544986     -0.975154      1.169617
#            1  0.000000  0.000000 0.000000      0.000000      0.000000
#            2 -1.220141 -1.206393 0.578410     -2.394927     -0.105726
#            5 -2.023292 -2.015452 0.637105     -3.311981     -0.809457
#            6 -2.602390 -2.590851 0.648490     -3.919844     -1.361627
#            7 -2.867788 -2.861398 0.670007     -4.207520     -1.563670
#
# MCMC DIAGNOSTICS
# ======================================================================
# Mean acceptance fraction: 0.520
# Min / Max acceptance fraction: 0.507 / 0.534
# Approximate effective sample size: 134042
#
# POSTERIOR PREDICTIVE MODEL FIT (PAIRWISE WINS)
# ======================================================================
# Chi-square statistic: 7.29
# Number of pairwise comparisons: 21
# Average chi-square per comparison: 0.35
# Fit assessment: Good model fit
#
# ======================================================================
# SUPERIORITY TEST RESULTS
# Target: FlowMOP
# Testing against: ['FlowCut', 'PeacoQC']
# ======================================================================
#
# FlowMOP vs FlowCut:
#   BF(FlowMOP > FlowCut): 5.39
#   Evidence: Moderate evidence  (P=0.844)
#   Ability difference: 0.579 ± 0.578
#   95% CI: [-0.547, 1.729]
#
# FlowMOP vs PeacoQC:
#   BF(FlowMOP > PeacoQC): 13.43
#   Evidence: Strong evidence  (P=0.931)
#   Ability difference: 0.844 ± 0.584
#   95% CI: [-0.276, 2.008]
#
# ======================================================================
# TEST 2: Is Benchmarker 5 INFERIOR to Benchmarkers 1, 2, 3, and 4?
# ======================================================================
#
# Posterior Statistics (Reference: Expert 1 = 0)
# ======================================================================
#  benchmarker      mean    median      std  95%_CI_lower  95%_CI_upper
#            3  1.016727  1.013749 0.605587     -0.160125      2.236555
#            4  0.114645  0.122168 0.544986     -0.975154      1.169617
#            1  0.000000  0.000000 0.000000      0.000000      0.000000
#            2 -1.220141 -1.206393 0.578410     -2.394927     -0.105726
#            5 -2.023292 -2.015452 0.637105     -3.311981     -0.809457
#            6 -2.602390 -2.590851 0.648490     -3.919844     -1.361627
#            7 -2.867788 -2.861398 0.670007     -4.207520     -1.563670
#
# MCMC DIAGNOSTICS
# ======================================================================
# Mean acceptance fraction: 0.520
# Min / Max acceptance fraction: 0.507 / 0.534
# Approximate effective sample size: 134042
#
# POSTERIOR PREDICTIVE MODEL FIT (PAIRWISE WINS)
# ======================================================================
# Chi-square statistic: 7.29
# Number of pairwise comparisons: 21
# Average chi-square per comparison: 0.35
# Fit assessment: Good model fit
#
# ======================================================================
# INFERIORITY TEST RESULTS
# Target: FlowMOP
# Testing against: ['Expert 1', 'Expert 2', 'Expert 3', 'Expert 4']
# ======================================================================
#
# FlowMOP vs Expert 1:
#   BF(FlowMOP < Expert 1): 1999.00
#   Evidence: Decisive evidence  (P=1.000)
#   Ability difference: -2.023 ± 0.637
#   95% CI: [-3.312, -0.809]
#
# FlowMOP vs Expert 2:
#   BF(FlowMOP < Expert 2): 10.01
#   Evidence: Strong evidence  (P=0.909)
#   Ability difference: -0.803 ± 0.607
#   95% CI: [-2.015, 0.368]
#
# FlowMOP vs Expert 3:
#   BF(FlowMOP < Expert 3): 1000000027.28
#   Evidence: Decisive evidence  (P=1.000)
#   Ability difference: -3.040 ± 0.735
#   95% CI: [-4.519, -1.647]
#
# FlowMOP vs Expert 4:
#   BF(FlowMOP < Expert 4): 3046.62
#   Evidence: Decisive evidence  (P=1.000)
#   Ability difference: -2.138 ± 0.664
#   95% CI: [-3.481, -0.876]

# %%
# Visualizations
superiority_time = plot_posterior_differences(
    mcmc_results_time, 
    target=5, 
    compare_against=[6, 7],
    test_type='superiority')
plt.show()

inferiority_time = plot_posterior_differences(
    mcmc_results_time,
    target=5,
    compare_against=[1, 2, 3, 4], 
    test_type='inferiority'
)
plt.show()

# %% [markdown]
# ## Debris

# %%
mcmc_results_debris = run_bayesian_ranking_analysis(
    df=debris,
    n_walkers=32,
    n_steps=5000,
    n_burn=1000,
    prior_std=2.0,
    verbose=True,
)
# Out:
# Model type: plackett-luce
# Found 5 benchmarkers: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)]
# Using benchmarker 1 as reference (ability = 0)
# Running MCMC: 32 walkers, 5000 steps, 1000 burn-in
# Found 9 test rankings
# Average ranking length: 4.9
# Using 15 threads for parallel MCMC sampling
#
# Running MCMC with parallelization...
# MCMC Sampling: 100%|██████████| 5000/5000 [01:31<00:00, 54.80steps/s, Accept=0.598]
# MCMC complete!
# Mean acceptance rate: 0.598
# ✓ Good acceptance rate
# Effective sample size: ~123258 (96.3% efficiency)

# %%
# Test 2: Inferiority
print("\n" + "="*70)
print("TEST 2: Is Benchmarker 5 INFERIOR to Benchmarkers 1, 2, 3, and 4?")
print("="*70)

validation_debris = validate_model_fit(mcmc_results_debris, debris, verbose=True)

inferiority_analysis = analyze_posterior(
    results=mcmc_results_debris,
    target_benchmarker=5,
    compare_against=[1, 2, 3, 4],
    test_type='inferiority',
    credible_level=0.95,
    verbose=True,
    validation=validation_debris
)
# Out:
# ======================================================================
# TEST 2: Is Benchmarker 5 INFERIOR to Benchmarkers 1, 2, 3, and 4?
# ======================================================================
#
# MODEL VALIDATION
# ==================================================
# Chi-square statistic: 5.57
# Number of pairwise comparisons: 10
# Average chi-square per comparison: 0.56
# ✓ Good model fit
#
# Posterior Statistics (Reference: Expert 1 = 0)
# ======================================================================
#  benchmarker      mean    median      std  95%_CI_lower  95%_CI_upper
#            2  1.828302  1.810813 0.631743      0.641859      3.094388
#            3  1.792131  1.778835 0.664176      0.530028      3.132303
#            4  0.279834  0.281463 0.562452     -0.822584      1.383867
#            1  0.000000  0.000000 0.000000      0.000000      0.000000
#            5 -0.651201 -0.639898 0.614644     -1.898000      0.522881
#
# MCMC DIAGNOSTICS
# ======================================================================
# Mean acceptance fraction: 0.598
# Min / Max acceptance fraction: 0.584 / 0.614
# Approximate effective sample size: 123258
#
# POSTERIOR PREDICTIVE MODEL FIT (PAIRWISE WINS)
# ======================================================================
# Chi-square statistic: 5.57
# Number of pairwise comparisons: 10
# Average chi-square per comparison: 0.56
# Fit assessment: Good model fit
#
# ======================================================================
# INFERIORITY TEST RESULTS
# Target: FlowMOP
# Testing against: ['Expert 1', 'Expert 2', 'Expert 3', 'Expert 4']
# ======================================================================
#
# FlowMOP vs Expert 1:
#   BF(FlowMOP < Expert 1): 5.99
#   Evidence: Moderate evidence  (P=0.857)
#   Ability difference: -0.651 ± 0.615
#   95% CI: [-1.898, 0.523]
#
# FlowMOP vs Expert 2:
#   BF(FlowMOP < Expert 2): 4570.43
#   Evidence: Decisive evidence  (P=1.000)
#   Ability difference: -2.480 ± 0.743
#   95% CI: [-4.005, -1.092]
#
# FlowMOP vs Expert 3:
#   BF(FlowMOP < Expert 3): 2975.74
#   Evidence: Decisive evidence  (P=1.000)
#   Ability difference: -2.443 ± 0.764
#   95% CI: [-4.004, -1.011]
#
# FlowMOP vs Expert 4:
#   BF(FlowMOP < Expert 4): 13.12
#   Evidence: Strong evidence  (P=0.929)
#   Ability difference: -0.931 ± 0.648
#   95% CI: [-2.258, 0.296]

# %%
inferiority_debris = plot_posterior_differences(
    mcmc_results_debris,
    target=5,
    compare_against=[1, 2, 3, 4], 
    test_type='inferiority'
)
plt.show()

# %% [markdown]
# ## Doublets

# %%
mcmc_results_doublets = run_bayesian_ranking_analysis(
    df=doublets,
    n_walkers=32,
    n_steps=5000,
    n_burn=1000,
    prior_std=2.0,
    verbose=True,
)
# Out:
# Model type: plackett-luce
# Found 5 benchmarkers: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)]
# Using benchmarker 1 as reference (ability = 0)
# Running MCMC: 32 walkers, 5000 steps, 1000 burn-in
# Found 9 test rankings
# Average ranking length: 4.9
# Using 15 threads for parallel MCMC sampling
#
# Running MCMC with parallelization...
# MCMC Sampling: 100%|██████████| 5000/5000 [01:39<00:00, 50.18steps/s, Accept=0.597]
# MCMC complete!
# Mean acceptance rate: 0.597
# ✓ Good acceptance rate
# Effective sample size: ~128003 (100.0% efficiency)

# %%
# Test 2: Inferiority
print("\n" + "="*70)
print("TEST 2: Is Benchmarker 5 INFERIOR to Benchmarkers 1, 2, 3, and 4?")
print("="*70)

validation_doublets = validate_model_fit(mcmc_results_doublets, doublets, verbose=True)

inferiority_analysis = analyze_posterior(
    results=mcmc_results_doublets,
    target_benchmarker=5,
    compare_against=[1, 2, 3, 4],
    test_type='inferiority',
    credible_level=0.95,
    verbose=True,
    validation=validation_doublets
)
# Out:
# ======================================================================
# TEST 2: Is Benchmarker 5 INFERIOR to Benchmarkers 1, 2, 3, and 4?
# ======================================================================
#
# MODEL VALIDATION
# ==================================================
# Chi-square statistic: 4.92
# Number of pairwise comparisons: 10
# Average chi-square per comparison: 0.49
# ✓ Good model fit
#
# Posterior Statistics (Reference: Expert 1 = 0)
# ======================================================================
#  benchmarker      mean    median      std  95%_CI_lower  95%_CI_upper
#            3  1.355116  1.350800 0.615931      0.167469      2.595272
#            1  0.000000  0.000000 0.000000      0.000000      0.000000
#            2 -0.255962 -0.244686 0.567832     -1.391364      0.836690
#            4 -0.414803 -0.398984 0.574904     -1.569594      0.693386
#            5 -0.822618 -0.812804 0.571155     -1.981071      0.267555
#
# MCMC DIAGNOSTICS
# ======================================================================
# Mean acceptance fraction: 0.597
# Min / Max acceptance fraction: 0.581 / 0.608
# Approximate effective sample size: 128003
#
# POSTERIOR PREDICTIVE MODEL FIT (PAIRWISE WINS)
# ======================================================================
# Chi-square statistic: 4.92
# Number of pairwise comparisons: 10
# Average chi-square per comparison: 0.49
# Fit assessment: Good model fit
#
# ======================================================================
# INFERIORITY TEST RESULTS
# Target: FlowMOP
# Testing against: ['Expert 1', 'Expert 2', 'Expert 3', 'Expert 4']
# ======================================================================
#
# FlowMOP vs Expert 1:
#   BF(FlowMOP < Expert 1): 13.42
#   Evidence: Strong evidence  (P=0.931)
#   Ability difference: -0.823 ± 0.571
#   95% CI: [-1.981, 0.268]
#
# FlowMOP vs Expert 2:
#   BF(FlowMOP < Expert 2): 4.90
#   Evidence: Moderate evidence  (P=0.830)
#   Ability difference: -0.567 ± 0.595
#   95% CI: [-1.756, 0.572]
#
# FlowMOP vs Expert 3:
#   BF(FlowMOP < Expert 3): 2611.24
#   Evidence: Decisive evidence  (P=1.000)
#   Ability difference: -2.178 ± 0.692
#   95% CI: [-3.606, -0.883]
#
# FlowMOP vs Expert 4:
#   BF(FlowMOP < Expert 4): 2.91
#   Evidence: Anecdotal evidence  (P=0.744)
#   Ability difference: -0.408 ± 0.624
#   95% CI: [-1.631, 0.816]

# %%
inferiority_doublets = plot_posterior_differences(
    mcmc_results_doublets,
    target=5,
    compare_against=[1, 2, 3, 4], 
    test_type='inferiority'
)
plt.show()

# %% [markdown]
# # Figures plottings

# %%
from bayesian_analysis import plot_average_scores, plot_ranking_heatmap, plot_posterior_analysis

# %%
sample_names = [
    "Mouse DRG", "Mouse Skin", "Human Cultured T Cells", "Mouse Bone Marrow", "Mouse Spleen", "Mouse Blood", "Mouse Brain", "Mouse CNS", "Human Liver"
]

# %% [markdown]
# ## Time

# %%
time.columns = sample_names

# %%
from pathlib import Path
from bayesian_analysis import plot_ranking_panel

export_dir = Path("svg_exports")
export_dir.mkdir(parents=True, exist_ok=True)

fig = plot_ranking_panel(
    df=time,
    figsize=(16, 7),
    heatmap_title="Rankings Across Datasets",
    average_title="Average Rankings Score",
)
fig.savefig(export_dir / "time_ranking_panel.svg", format="svg", bbox_inches="tight")
plt.show()
print(f"Saved: {(export_dir / 'time_ranking_panel.svg').resolve()}")
# Out:
# Saved: D:\github_remotes\FlowMOP_paper\figs_data\fig_3_data\fig_3_analysis\svg_exports\time_ranking_panel.svg

# %% [markdown]
# ## Debris

# %%
from pathlib import Path
export_dir = Path("svg_exports")
export_dir.mkdir(parents=True, exist_ok=True)

debris.columns = sample_names

fig = plot_ranking_panel(
    df=debris,
    figsize=(16, 7),
    heatmap_title="Rankings Across Datasets",
    average_title="Average Rankings Score",
)
fig.savefig(export_dir / "debris_ranking_panel.svg", format="svg", bbox_inches="tight")
plt.show()
print(f"Saved: {(export_dir / 'debris_ranking_panel.svg').resolve()}")
# Out:
# Saved: D:\github_remotes\FlowMOP_paper\figs_data\fig_3_data\fig_3_analysis\svg_exports\debris_ranking_panel.svg

# %% [markdown]
# ## Doublets

# %%
from pathlib import Path
export_dir = Path("svg_exports")
export_dir.mkdir(parents=True, exist_ok=True)

doublets.columns = sample_names

fig = plot_ranking_panel(
    df=doublets,
    figsize=(16, 7),
    heatmap_title="Rankings Across Datasets",
    average_title="Average Rankings Score",
)
fig.savefig(export_dir / "doublets_ranking_panel.svg", format="svg", bbox_inches="tight")
plt.show()
print(f"Saved: {(export_dir / 'doublets_ranking_panel.svg').resolve()}")
# Out:
# Saved: D:\github_remotes\FlowMOP_paper\figs_data\fig_3_data\fig_3_analysis\svg_exports\doublets_ranking_panel.svg
